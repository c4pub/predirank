# %% [markdown]
# # Comparing Classifier Accuracy: Numerized  Datasets
#
# This notebook computes a ranking of selected classification algorithms applied to a collection of datasets. The primary focus is on classifiers from the sklearn library and their application to tabular data.
#
# Sklearn classifiers require numerical data for operation. Consequently, categorical data must be 'numerized', or converted into numerical form using one-hot encoding.
#
# This tool is designed to automatically transform tabular data into a numerical format that is compatible with sklearn classifiers.
#
#
# https://github.com/c4pub/predirank

# %% [markdown]
# ### Get remote ressources

# %%
#@title

# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
print("*** Get remote files - start")
# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

import urllib
import shutil
# !pip install catboost

csv_file_lst = [
    "basic-abalone-sex.csv",
    "basic-adult-reduced.csv",
    "basic-breast-cancer-wisconsin.csv",
    "basic-cardiotocography.csv",
    "basic-credit-approval.csv",
    "basic-data_banknote_authentication.csv",
    "basic-diabetes.csv",
    "basic-digits.csv",
    "basic-ionosphere.data.csv",
    "basic-iris.csv",
    "basic-pima-indians-diabetes.csv",
    "basic-sonar.all-data.csv",
    "basic-titanic.csv",
    "basic-wheat-seeds.csv",
    "basic-wine.csv",
    "basic-winequality-white.csv",
    # ---------------------------------
    "dset-abalone.csv",
    "dset-acute-inflammation.csv",
    "dset-acute-nephritis.csv",
    "dset-adult_train-reduced.csv",
    "dset-annealing_train.csv",
    "dset-arrhythmia.csv",
    "dset-audiology-std_train.csv",
    "dset-audiology-std_train-patrons_repetidos.csv",
    "dset-balance-scale.csv",
    "dset-balloons.csv",
    "dset-bank.csv",
    "dset-blood.csv",
    "dset-breast-cancer.csv",
    "dset-breast-cancer-wisc.csv",
    "dset-breast-cancer-wisc-diag.csv",
    "dset-breast-cancer-wisc-prog.csv",
    "dset-breast-tissue.csv",
    "dset-car.csv",
    "dset-cardiotocography-10clases.csv",
    "dset-cardiotocography-3clases.csv",
    "dset-chess-krvk.csv",
    "dset-chess-krvkp.csv",
    "dset-congressional-voting.csv",
    "dset-conn-bench-sonar-mines-rocks.csv",
    "dset-conn-bench-vowel-deterding_train.csv",
    "dset-connect-4-reduced.csv",
    "dset-contrac.csv",
    "dset-credit-approval.csv",
    "dset-cylinder-bands.csv",
    "dset-dermatology.csv",
    "dset-echocardiogram.csv",
    "dset-ecoli.csv",
    "dset-energy-y1.csv",
    "dset-energy-y2.csv",
    "dset-fertility.csv",
    "dset-flags.csv",
    "dset-glass.csv",
    "dset-haberman-survival.csv",
    "dset-hayes-roth_train.csv",
    "dset-heart-cleveland.csv",
    "dset-heart-hungarian.csv",
    "dset-heart-switzerland.csv",
    "dset-heart-va.csv",
    "dset-hepatitis.csv",
    "dset-hill-valley_train.csv",
    "dset-horse-colic_train.csv",
    "dset-ilpd-indian-liver.csv",
    "dset-image-segmentation_test.csv",
    "dset-ionosphere.csv",
    "dset-iris.csv",
    "dset-led-display.csv",
    "dset-lenses.csv",
    "dset-letter-reduced.csv",
    "dset-libras.csv",
    "dset-low-res-spect.csv",
    "dset-lung-cancer.csv",
    "dset-lymphography.csv",
    "dset-magic.csv",
    "dset-mammographic.csv",
    "dset-miniboone-reduced.csv",
    "dset-molec-biol-promoter.csv",
    "dset-molec-biol-splice.csv",
    "dset-monks-1_test.csv",
    "dset-monks-2_test.csv",
    "dset-monks-3_test.csv",
    "dset-mushroom.csv",
    "dset-musk-1.csv",
    "dset-musk-2-reduced.csv",
    "dset-nursery.csv",
    "dset-oocytes_merluccius_nucleus_4d.csv",
    "dset-oocytes_merluccius_states_2f.csv",
    "dset-oocytes_trisopterus_nucleus_2f.csv",
    "dset-oocytes_trisopterus_states_5b.csv",
    "dset-optical_train.csv",
    "dset-ozone.csv",
    "dset-page-blocks.csv",
    "dset-parkinsons.csv",
    "dset-pendigits_train.csv",
    "dset-pima.csv",
    "dset-pittsburg-bridges-MATERIAL.csv",
    "dset-pittsburg-bridges-REL-L.csv",
    "dset-pittsburg-bridges-SPAN.csv",
    "dset-pittsburg-bridges-T-OR-D.csv",
    "dset-pittsburg-bridges-TYPE.csv",
    "dset-planning.csv",
    "dset-plant-margin.csv",
    "dset-plant-shape.csv",
    "dset-plant-texture.csv",
    "dset-post-operative.csv",
    "dset-primary-tumor.csv",
    "dset-ringnorm.csv",
    "dset-seeds.csv",
    "dset-semeion-reduced.csv",
    "dset-soybean_test.csv",
    "dset-spambase.csv",
    "dset-spect_test.csv",
    "dset-spectf_test.csv",
    "dset-statlog-australian-credit.csv",
    "dset-statlog-german-credit.csv",
    "dset-statlog-heart.csv",
    "dset-statlog-image.csv",
    "dset-statlog-landsat_train.csv",
    "dset-statlog-shuttle_train-reduced.csv",
    "dset-statlog-vehicle.csv",
    "dset-steel-plates.csv",
    "dset-synthetic-control.csv",
    "dset-teaching.csv",
    "dset-thyroid_train.csv",
    "dset-tic-tac-toe.csv",
    "dset-titanic.csv",
    "dset-trains.csv",
    "dset-twonorm.csv",
    "dset-vertebral-column-2clases.csv",
    "dset-vertebral-column-3clases.csv",
    "dset-vertebral-datos_orixinais-column_2C_weka.csv",
    "dset-vertebral-datos_orixinais-column_3C_weka.csv",
    "dset-wall-following.csv",
    "dset-waveform.csv",
    "dset-waveform-noise.csv",
    "dset-wine.csv",
    "dset-wine-quality-red.csv",
    "dset-wine-quality-white.csv",
    "dset-yeast.csv",
    "dset-zoo.csv",
]

remote_data_lst = []
for crt_file in csv_file_lst :
    new_row = {'file': crt_file, 'url':"https://raw.githubusercontent.com/c4pub/predirank/main/data/"}
    remote_data_lst.append(new_row)

remote_script_list = [
                {'file': 'predirank.py', 'url': "https://raw.githubusercontent.com/c4pub/predirank/main/src/"},
                {'file': 'deodel.py', 'url': "https://raw.githubusercontent.com/c4pub/deodel/main/"},
                {'file': 'deodel2.py', 'url': "https://raw.githubusercontent.com/c4pub/deodel/main/"},
            ]

remote_file_list = remote_script_list + remote_data_lst

for remote_entry in remote_file_list :
    file_name = remote_entry['file']
    url = remote_entry['url'] + file_name
    print("remote - url:", url)
    with urllib.request.urlopen(url) as response, open(file_name, 'wb') as out_file:
        shutil.copyfileobj(response, out_file)

# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
print("*** Get remote files - stop")
# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Out:
# *** Get remote files - start
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/src/predirank.py
# remote - url: https://raw.githubusercontent.com/c4pub/deodel/main/deodel.py
# remote - url: https://raw.githubusercontent.com/c4pub/deodel/main/deodel2.py
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-abalone-sex.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-adult-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-breast-cancer-wisconsin.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-cardiotocography.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-credit-approval.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-data_banknote_authentication.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-diabetes.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-digits.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-ionosphere.data.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-iris.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-pima-indians-diabetes.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-sonar.all-data.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-titanic.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-wheat-seeds.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-wine.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/basic-winequality-white.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-abalone.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-acute-inflammation.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-acute-nephritis.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-adult_train-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-annealing_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-arrhythmia.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-audiology-std_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-audiology-std_train-patrons_repetidos.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-balance-scale.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-balloons.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-bank.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-blood.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-breast-cancer.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-breast-cancer-wisc.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-breast-cancer-wisc-diag.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-breast-cancer-wisc-prog.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-breast-tissue.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-car.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-cardiotocography-10clases.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-cardiotocography-3clases.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-chess-krvk.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-chess-krvkp.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-congressional-voting.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-conn-bench-sonar-mines-rocks.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-conn-bench-vowel-deterding_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-connect-4-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-contrac.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-credit-approval.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-cylinder-bands.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-dermatology.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-echocardiogram.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-ecoli.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-energy-y1.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-energy-y2.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-fertility.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-flags.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-glass.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-haberman-survival.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-hayes-roth_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-heart-cleveland.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-heart-hungarian.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-heart-switzerland.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-heart-va.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-hepatitis.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-hill-valley_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-horse-colic_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-ilpd-indian-liver.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-image-segmentation_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-ionosphere.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-iris.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-led-display.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-lenses.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-letter-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-libras.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-low-res-spect.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-lung-cancer.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-lymphography.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-magic.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-mammographic.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-miniboone-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-molec-biol-promoter.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-molec-biol-splice.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-monks-1_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-monks-2_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-monks-3_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-mushroom.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-musk-1.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-musk-2-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-nursery.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-oocytes_merluccius_nucleus_4d.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-oocytes_merluccius_states_2f.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-oocytes_trisopterus_nucleus_2f.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-oocytes_trisopterus_states_5b.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-optical_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-ozone.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-page-blocks.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-parkinsons.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pendigits_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pima.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pittsburg-bridges-MATERIAL.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pittsburg-bridges-REL-L.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pittsburg-bridges-SPAN.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pittsburg-bridges-T-OR-D.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-pittsburg-bridges-TYPE.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-planning.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-plant-margin.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-plant-shape.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-plant-texture.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-post-operative.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-primary-tumor.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-ringnorm.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-seeds.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-semeion-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-soybean_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-spambase.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-spect_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-spectf_test.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-australian-credit.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-german-credit.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-heart.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-image.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-landsat_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-shuttle_train-reduced.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-statlog-vehicle.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-steel-plates.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-synthetic-control.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-teaching.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-thyroid_train.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-tic-tac-toe.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-titanic.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-trains.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-twonorm.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-vertebral-column-2clases.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-vertebral-column-3clases.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-vertebral-datos_orixinais-column_2C_weka.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-vertebral-datos_orixinais-column_3C_weka.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-wall-following.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-waveform.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-waveform-noise.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-wine.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-wine-quality-red.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-wine-quality-white.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-yeast.csv
# remote - url: https://raw.githubusercontent.com/c4pub/predirank/main/data/dset-zoo.csv
# *** Get remote files - stop

# %%
    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    def CrtTimeStamp(display_flag = True) :
        import datetime

        in_time_stamp = datetime.datetime.now()
        time_str = in_time_stamp.strftime("%Y-%m-%d %H:%M:%S")
        out_str = "time_stamp: %s" % (time_str)
        if display_flag :
            print(out_str)

print()
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
CrtTimeStamp()
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print()
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# time_stamp: 2024-03-03 23:36:58
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# ### Test Execution

# %%
#@title

from IPython.display import Javascript
display(Javascript('''
google.colab.output.setIframeHeight(0, true, {maxHeight: 100000})
'''))

# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
def GetSelClassifierListSk() :

    import sklearn.calibration
    import sklearn.discriminant_analysis
    import sklearn.ensemble
    import sklearn.gaussian_process
    import sklearn.linear_model
    import sklearn.mixture
    import sklearn.naive_bayes
    import sklearn.neighbors
    import sklearn.neural_network
    import sklearn.semi_supervised
    import sklearn.svm
    import sklearn.tree

    classifier_lst = [
                        # First term is classifier, second: alias name/id
                        [sklearn.calibration.CalibratedClassifierCV(), None],
                        [sklearn.discriminant_analysis.LinearDiscriminantAnalysis(), None],
                        [sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis(), None],
                        [sklearn.ensemble.AdaBoostClassifier(), None],
                        [sklearn.ensemble.BaggingClassifier(), None],
                        [sklearn.ensemble.ExtraTreesClassifier(), None],
                        [sklearn.ensemble.GradientBoostingClassifier(), None],
                        [sklearn.ensemble.HistGradientBoostingClassifier(), None],
                        [sklearn.ensemble.RandomForestClassifier(), None],
                        # [sklearn.ensemble.VotingClassifier(), None],
                        [sklearn.gaussian_process.GaussianProcessClassifier(), None],
                        [sklearn.linear_model.LogisticRegression(), None],
                        [sklearn.linear_model.LogisticRegressionCV(), None],
                        [sklearn.linear_model.PassiveAggressiveClassifier(), None],
                        [sklearn.linear_model.Perceptron(), None],
                        [sklearn.linear_model.RidgeClassifier(), None],
                        [sklearn.linear_model.RidgeClassifierCV(), None],
                        [sklearn.linear_model.SGDClassifier(), None],
                        [sklearn.mixture.BayesianGaussianMixture(), None],
                        [sklearn.mixture.GaussianMixture(), None],
                        # [sklearn.multiclass.OneVsOneClassifier(), None],
                        # [sklearn.multiclass.OneVsRestClassifier(), None],
                        # [sklearn.multiclass.OutputCodeClassifier(), None],
                        # [sklearn.multioutput.ClassifierChain(), None],
                        # [sklearn.multioutput.MultiOutputClassifier(), None],
                        [sklearn.naive_bayes.BernoulliNB(), None],
                        [sklearn.naive_bayes.GaussianNB(), None],
                        [sklearn.naive_bayes.MultinomialNB(), None],
                        [sklearn.neighbors.KNeighborsClassifier(), None],
                        [sklearn.neighbors.NearestCentroid(), None],
                        [sklearn.neighbors.RadiusNeighborsClassifier(), None],
                        [sklearn.neural_network.MLPClassifier(), None],
                        [sklearn.semi_supervised.LabelPropagation(), None],
                        [sklearn.semi_supervised.LabelSpreading(), None],
                        [sklearn.svm.LinearSVC(), None],
                        [sklearn.svm.NuSVC(), None],
                        [sklearn.svm.OneClassSVM(), None],
                        [sklearn.svm.SVC(), None],
                        [sklearn.tree.DecisionTreeClassifier(), None],
                        [sklearn.tree.ExtraTreeClassifier(), None],
                    ]

    return classifier_lst

# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
def GetClassifierListExtra() :

    import catboost
    import sklearn.neighbors
    import deodel
    import deodel2
    import predirank

    class XGBClassifierWrap:
        def __init__(self, **kwargs):
            from sklearn.preprocessing import LabelEncoder

            self.clf = None
            self.aux_param = kwargs  # Store the parameters
            self.le = LabelEncoder()
            self.num_class = 0

        def __repr__(self):
            '''Returns representation of the object'''
            return("{}({!r})".format(self.__class__.__name__, self.aux_param))

        def fit(self, X, y):
            from xgboost import XGBClassifier
            import numpy as np

            # Encode the labels before fitting
            y_encoded = self.le.fit_transform(y)

            # Determine class number
            self.num_class = len(np.unique(y_encoded))

            fit_param = dict(self.aux_param)
            if self.num_class > 2:
                fit_param['objective'] = 'multi:softprob'
                fit_param['num_class'] = self.num_class

            self.clf = XGBClassifier(**fit_param)
            self.clf.fit(X, y_encoded)

        def predict(self, X):
            # Use the XGBClassifier's predict method
            y_pred = self.clf.predict(X)
            y_out = self.le.inverse_transform(y_pred)
            return y_out

    classifier_lst = [
                        # First term is classifier, second: alias name/id
                        [XGBClassifierWrap(), None],
                        [catboost.CatBoostClassifier(logging_level='Silent'), 'CatBoostClassifier'],
                        # [sklearn.neighbors.KNeighborsClassifier(n_neighbors=1), None],
                        [deodel.DeodataDelangaClassifier(), None],
                        [deodel2.DeodelSecond(), None],
                        [predirank.RandPredictor({'rand_seed': 42}), '<<< Random Baseline >>>'],
                    ]

    return classifier_lst

# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
def GetCsvDataList() :

    csv_file_lst = [
        # First term is file name, second: index of target (-1/last by default)
        ["basic-abalone-sex.csv"],
        ["basic-adult-reduced.csv"],
        ["basic-breast-cancer-wisconsin.csv"],
        ["basic-cardiotocography.csv"],
        ["basic-credit-approval.csv"],
        ["basic-data_banknote_authentication.csv"],
        ["basic-diabetes.csv"],
        ["basic-digits.csv"],
        ["basic-ionosphere.data.csv"],
        ["basic-iris.csv"],
        ["basic-pima-indians-diabetes.csv"],
        ["basic-sonar.all-data.csv", -1],
        ["basic-titanic.csv", 1],
        ["basic-wheat-seeds.csv"],
        ["basic-wine.csv"],
        ["basic-winequality-white.csv"],
        # -----------------------------------
        ["dset-abalone.csv"],
        ["dset-acute-inflammation.csv"],
        ["dset-acute-nephritis.csv"],
        ["dset-adult_train-reduced.csv"],
        ["dset-annealing_train.csv"],
        ["dset-arrhythmia.csv"],
        ["dset-audiology-std_train.csv"],
        ["dset-audiology-std_train-patrons_repetidos.csv"],
        ["dset-balance-scale.csv"],
        ["dset-balloons.csv"],
        ["dset-bank.csv"],
        ["dset-blood.csv"],
        ["dset-breast-cancer.csv"],
        ["dset-breast-cancer-wisc.csv"],
        ["dset-breast-cancer-wisc-diag.csv"],
        ["dset-breast-cancer-wisc-prog.csv"],
        ["dset-breast-tissue.csv"],
        ["dset-car.csv"],
        ["dset-cardiotocography-10clases.csv"],
        ["dset-cardiotocography-3clases.csv"],
        ["dset-chess-krvk.csv"],
        ["dset-chess-krvkp.csv"],
        ["dset-congressional-voting.csv"],
        ["dset-conn-bench-sonar-mines-rocks.csv"],
        ["dset-conn-bench-vowel-deterding_train.csv"],
        ["dset-connect-4-reduced.csv"],
        ["dset-contrac.csv"],
        ["dset-credit-approval.csv"],
        ["dset-cylinder-bands.csv"],
        ["dset-dermatology.csv"],
        ["dset-echocardiogram.csv"],
        ["dset-ecoli.csv"],
        ["dset-energy-y1.csv"],
        ["dset-energy-y2.csv"],
        ["dset-fertility.csv"],
        ["dset-flags.csv"],
        ["dset-glass.csv"],
        ["dset-haberman-survival.csv"],
        ["dset-hayes-roth_train.csv"],
        ["dset-heart-cleveland.csv"],
        ["dset-heart-hungarian.csv"],
        ["dset-heart-switzerland.csv"],
        ["dset-heart-va.csv"],
        ["dset-hepatitis.csv"],
        ["dset-hill-valley_train.csv"],
        ["dset-horse-colic_train.csv"],
        ["dset-ilpd-indian-liver.csv"],
        ["dset-image-segmentation_test.csv"],
        ["dset-ionosphere.csv"],
        ["dset-iris.csv"],
        ["dset-led-display.csv"],
        ["dset-lenses.csv"],
        ["dset-letter-reduced.csv"],
        ["dset-libras.csv"],
        ["dset-low-res-spect.csv"],
        ["dset-lung-cancer.csv"],
        ["dset-lymphography.csv"],
        ["dset-magic.csv"],
        ["dset-mammographic.csv"],
        ["dset-miniboone-reduced.csv"],
        ["dset-molec-biol-promoter.csv"],
        ["dset-molec-biol-splice.csv"],
        ["dset-monks-1_test.csv"],
        ["dset-monks-2_test.csv"],
        ["dset-monks-3_test.csv"],
        ["dset-mushroom.csv"],
        ["dset-musk-1.csv"],
        ["dset-musk-2-reduced.csv"],
        ["dset-nursery.csv"],
        ["dset-oocytes_merluccius_nucleus_4d.csv"],
        ["dset-oocytes_merluccius_states_2f.csv"],
        ["dset-oocytes_trisopterus_nucleus_2f.csv"],
        ["dset-oocytes_trisopterus_states_5b.csv"],
        ["dset-optical_train.csv"],
        ["dset-ozone.csv"],
        ["dset-page-blocks.csv"],
        ["dset-parkinsons.csv"],
        ["dset-pendigits_train.csv"],
        ["dset-pima.csv"],
        ["dset-pittsburg-bridges-MATERIAL.csv"],
        ["dset-pittsburg-bridges-REL-L.csv"],
        ["dset-pittsburg-bridges-SPAN.csv"],
        ["dset-pittsburg-bridges-T-OR-D.csv"],
        ["dset-pittsburg-bridges-TYPE.csv"],
        ["dset-planning.csv"],
        ["dset-plant-margin.csv"],
        ["dset-plant-shape.csv"],
        ["dset-plant-texture.csv"],
        ["dset-post-operative.csv"],
        ["dset-primary-tumor.csv"],
        ["dset-ringnorm.csv"],
        ["dset-seeds.csv"],
        ["dset-semeion-reduced.csv"],
        ["dset-soybean_test.csv"],
        ["dset-spambase.csv"],
        ["dset-spect_test.csv"],
        ["dset-spectf_test.csv"],
        ["dset-statlog-australian-credit.csv"],
        ["dset-statlog-german-credit.csv"],
        ["dset-statlog-heart.csv"],
        ["dset-statlog-image.csv"],
        ["dset-statlog-landsat_train.csv"],
        ["dset-statlog-shuttle_train-reduced.csv"],
        ["dset-statlog-vehicle.csv"],
        ["dset-steel-plates.csv"],
        ["dset-synthetic-control.csv"],
        ["dset-teaching.csv"],
        ["dset-thyroid_train.csv"],
        ["dset-tic-tac-toe.csv"],
        ["dset-titanic.csv"],
        ["dset-trains.csv"],
        ["dset-twonorm.csv"],
        ["dset-vertebral-column-2clases.csv"],
        ["dset-vertebral-column-3clases.csv"],
        ["dset-vertebral-datos_orixinais-column_2C_weka.csv"],
        ["dset-vertebral-datos_orixinais-column_3C_weka.csv"],
        ["dset-wall-following.csv"],
        ["dset-waveform.csv"],
        ["dset-waveform-noise.csv"],
        ["dset-wine.csv"],
        ["dset-wine-quality-red.csv"],
        ["dset-wine-quality-white.csv"],
        ["dset-yeast.csv"],
        ["dset-zoo.csv"],
    ]
    return csv_file_lst

# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
def predirank_devtest() :

    import predirank

    print("- - - - - - - - - - - - - - - - - - ")
    print("- - - - - - - - - - - - - - - - - - ")
    print("- - - predirank_devtest")
    print()

    classifier_sk_lst = GetSelClassifierListSk()
    classifier_extra_lst = GetClassifierListExtra()
    classifier_lst = classifier_sk_lst + classifier_extra_lst

    predictor_list = classifier_lst
    file_data_list = GetCsvDataList()

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    data_location = "./"

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    iter_no = 3

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    random_seed = 42

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    test_fraction = 0.5

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
    array_limit_row_max = 2000
    array_limit_row_min = 12
    array_limit_col_max = 0

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

    data_process_mode = 'numeric'

    print("- - - - - - - - - - - - - - - - - - ")
    print("- - - data_process_mode:", data_process_mode)
    print("- - - - - - - - - - - - - - - - - - ")
    print()

    ret_data = predirank.BatchCsvAccuracyTest(predictor_list, file_data_list, data_location,
                                    iter_no, random_seed, test_fraction, data_process_mode,
                                    array_limit_row_max, array_limit_row_min, array_limit_col_max)
    print()
    print("- - - - - - - - - - - - - - - - - - ")
    print("- - - - - - - - - - - - - - - - - - ")
    print()

    # >- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("- - - test begin")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")

predirank_devtest()

import sys
import sklearn

print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("- - - - python version:", str(sys.version))
print("- - - - scikit-learn version:", str(sklearn.__version__))
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print()

print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print("- - - test end")
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
# Out:
# Streaming output truncated to the last 5000 lines.
# - - - - rank_score_avg: 0.6359649122807017
# - - - - rank_score_stdev: 0.14069311344162666
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelPropagation()
# - - - - rank_score_avg: 0.32456140350877194
# - - - - rank_score_stdev: 0.04019803241189332
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelSpreading()
# - - - - rank_score_avg: 0.3333333333333333
# - - - - rank_score_stdev: 0.05478068419647718
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LinearSVC()
# - - - - rank_score_avg: 0.9736842105263158
# - - - - rank_score_stdev: 0.026315789473684237
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NuSVC()
# - - - - rank_score_avg: 0.40789473684210525
# - - - - rank_score_stdev: 0.3634533504456088
# - - - - excpt_count: 1
# - - - - - - - - - - - -
# - - - - crt_classif: OneClassSVM()
# - - - - rank_score_avg: 0.07894736842105263
# - - - - rank_score_stdev: 0.02631578947368421
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SVC()
# - - - - rank_score_avg: 0.6885964912280702
# - - - - rank_score_stdev: 0.12225754267338909
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DecisionTreeClassifier()
# - - - - rank_score_avg: 0.38596491228070173
# - - - - rank_score_stdev: 0.08039606482378667
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreeClassifier()
# - - - - rank_score_avg: 0.2675438596491228
# - - - - rank_score_stdev: 0.12225754267338906
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: XGBClassifierWrap({})
# - - - - rank_score_avg: 0.7017543859649124
# - - - - rank_score_stdev: 0.1979523525683642
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: CatBoostClassifier
# - - - - rank_score_avg: 0.8333333333333334
# - - - - rank_score_stdev: 0.07931202333344355
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodataDelangaClassifier({})
# - - - - rank_score_avg: 0.17543859649122806
# - - - - rank_score_stdev: 0.015193428136569098
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodelSecond({})
# - - - - rank_score_avg: 0.23684210526315788
# - - - - rank_score_stdev: 0.02631578947368421
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: <<< Random Baseline >>>
# - - - - rank_score_avg: 0.14035087719298245
# - - - - rank_score_stdev: 0.015193428136569098
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# time_stamp: 2024-03-04 04:28:16
#
# --------------------------------------------------------------------------------
# - - - - dataset name: dset-vertebral-column-3clases.csv
#
# rank score avg      stdev  accuracy avg        xpt  classifier
# --------------------------------------------------------------------------------
# 0.9736842105263158  0.026> 0.8709677419354839  0    LinearSVC()
# 0.9649122807017544  0.027> 0.8666666666666667  0    LogisticRegressionCV()
# 0.9649122807017544  0.049> 0.8709677419354839  0    CalibratedClassifierCV()
# 0.8333333333333334  0.079> 0.8494623655913979  0    CatBoostClassifier
# 0.8333333333333334  0.107> 0.8473118279569892  0    LogisticRegression()
# 0.8333333333333334  0.107> 0.8473118279569892  0    ExtraTreesClassifier()
# 0.7675438596491228  0.117> 0.8430107526881722  0    GradientBoostingClassifier()
# 0.7631578947368421  0.138> 0.8408602150537634  0    RandomForestClassifier()
# 0.706140350877193   0.085> 0.8322580645161292  0    BaggingClassifier()
# 0.7017543859649124  0.197> 0.8344086021505377  0    XGBClassifierWrap({})
# 0.7017543859649124  0.141> 0.8301075268817204  0    SGDClassifier()
# 0.6885964912280702  0.122> 0.8322580645161292  0    SVC()
# 0.6842105263157895  0.157> 0.8301075268817204  0    HistGradientBoostingClassifier()
# 0.6798245614035088  0.164> 0.8322580645161289  0    PassiveAggressiveClassifier()
# 0.6578947368421053  0.177> 0.8236559139784946  0    GaussianNB()
# 0.6447368421052632  0.271> 0.8215053763440862  0    LinearDiscriminantAnalysis()
# 0.6359649122807017  0.140> 0.8279569892473119  0    MLPClassifier()
# 0.5964912280701754  0.134> 0.8193548387096774  0    GaussianProcessClassifier()
# 0.5921052631578947  0.047> 0.8193548387096774  0    RidgeClassifier()
# 0.5570175438596492  0.095> 0.8172043010752689  0    QuadraticDiscriminantAnalysis()
# 0.513157894736842   0.133> 0.8043010752688172  0    RidgeClassifierCV()
# 0.4166666666666667  0.098> 0.7935483870967741  0    Perceptron()
# 0.40789473684210525 0.363> 0.5526881720430108  1    NuSVC()
# 0.38596491228070173 0.080> 0.7806451612903226  0    DecisionTreeClassifier()
# 0.3333333333333333  0.054> 0.7720430107526881  0    LabelSpreading()
# 0.32894736842105265 0.086> 0.7677419354838709  0    KNeighborsClassifier()
# 0.32456140350877194 0.040> 0.7698924731182796  0    LabelPropagation()
# 0.32456140350877194 0.119> 0.7655913978494624  0    BernoulliNB()
# 0.30701754385964913 0.135> 0.675268817204301   0    AdaBoostClassifier()
# 0.2675438596491228  0.122> 0.7225806451612904  0    ExtraTreeClassifier()
# 0.25877192982456143 0.042> 0.7440860215053763  0    NearestCentroid()
# 0.23684210526315788 0.026> 0.7354838709677419  0    DeodelSecond({})
# 0.17543859649122806 0.015> 0.664516129032258   0    DeodataDelangaClassifier({})
# 0.14035087719298245 0.015> 0.35698924731182796 0    <<< Random Baseline >>>
# 0.09210526315789473 0.026> 0.18279569892473116 0    GaussianMixture()
# 0.09210526315789473 0.026> 0.18279569892473116 0    BayesianGaussianMixture()
# 0.07894736842105263 0.026> 0.1763440860215054  0    OneClassSVM()
# 0.0175438596491228> 0.007> 0.0                 3    RadiusNeighborsClassifier()
# 0.0175438596491228> 0.007> 0.0                 3    MultinomialNB()
# --------------------------------------------------------------------------------
#
# - - - - - - - - -
# - - - - dataset: dset-vertebral-datos_orixinais-column_2C_weka.csv
# - - - - - - - - -
# - - - data processing - retrieved csv
# - - - - - - input_no_row: 310
# - - - - - - input_no_col: 7
# - - - - - - input_targ_idx: -1
# - - - - - - insput_start_row: 0
# - - - - - - - - -
# - - - data sample:
#     [63.0278175, 22.55258597, 39.60911701, 40.47523153, 98.67291675, -0.254399986, 'Abnormal']
#     [39.05695098, 10.06099147, 25.01537822, 28.99595951, 114.4054254, 4.564258645, 'Abnormal']
#     [68.83202098, 22.21848205, 50.09219357, 46.61353893, 105.9851355, -3.530317314, 'Abnormal']
#     [69.29700807, 24.65287791, 44.31123813, 44.64413017, 101.8684951, 11.21152344, 'Abnormal']
#     [49.71285934, 9.652074879, 28.317406, 40.06078446, 108.1687249, 7.918500615, 'Abnormal']
#     ...
#     [47.90356517, 13.61668819, 36, 34.28687698, 117.4490622, -4.245395422, 'Normal']
#     [53.93674778, 20.72149628, 29.22053381, 33.21525149, 114.365845, -0.421010392, 'Normal']
#     [61.44659663, 22.6949683, 46.17034732, 38.75162833, 125.6707246, -2.707879517, 'Normal']
#     [45.25279209, 8.693157364, 41.5831264, 36.55963472, 118.5458418, 0.214750167, 'Normal']
#     [33.84164075, 5.073991409, 36.64123294, 28.76764934, 123.9452436, -0.199249089, 'Normal']
# - - - - - - - - -
#
# - - - data processing - target extracted
# - - - data processing - one-hot encoded
# - - - - - - onehot_no_row: 310
# - - - - - - onehot_no_col: 6
# - - - data processing - size limitation
# - - - - - - proc_no_row: 310
# - - - - - - proc_no_col: 6
# - - - data row number unchanged
# - - - data col number unchanged
# - - - data processing - finished
# - - - - - - proc_no_row: 310
# - - - - - - proc_no_col: 6
# - - - data sample:
#     [63.0278175, 22.55258597, 39.60911701, 40.47523153, 98.67291675, -0.254399986]
#     [39.05695098, 10.06099147, 25.01537822, 28.99595951, 114.4054254, 4.564258645]
#     [68.83202098, 22.21848205, 50.09219357, 46.61353893, 105.9851355, -3.530317314]
#     [69.29700807, 24.65287791, 44.31123813, 44.64413017, 101.8684951, 11.21152344]
#     [49.71285934, 9.652074879, 28.317406, 40.06078446, 108.1687249, 7.918500615]
#     ...
#     [47.90356517, 13.61668819, 36, 34.28687698, 117.4490622, -4.245395422]
#     [53.93674778, 20.72149628, 29.22053381, 33.21525149, 114.365845, -0.421010392]
#     [61.44659663, 22.6949683, 46.17034732, 38.75162833, 125.6707246, -2.707879517]
#     [45.25279209, 8.693157364, 41.5831264, 36.55963472, 118.5458418, 0.214750167]
#     [33.84164075, 5.073991409, 36.64123294, 28.76764934, 123.9452436, -0.199249089]
#
# --------------------------------------------------------------------------------
# time_stamp: 2024-03-04 04:28:16
# - - - - - - - - - - - -
# - - - - classif_id: CalibratedClassifierCV()
# - - - - - - - - accuracy: 0.8064516129032259
# - - - - - - - - std_dev: 0.017069363297190887
# - - - - - - - - time_delta: 0.26650071144104004
# - - - - classif_id: LinearDiscriminantAnalysis()
# - - - - - - - - accuracy: 0.8559139784946237
# - - - - - - - - std_dev: 0.03553271320829746
# - - - - - - - - time_delta: 0.025669336318969727
# - - - - classif_id: QuadraticDiscriminantAnalysis()
# - - - - - - - - accuracy: 0.8344086021505376
# - - - - - - - - std_dev: 0.026073883124692793
# - - - - - - - - time_delta: 0.020229816436767578
# - - - - classif_id: AdaBoostClassifier()
# - - - - - - - - accuracy: 0.7913978494623656
# - - - - - - - - std_dev: 0.026860206444724317
# - - - - - - - - time_delta: 0.2905616760253906
# - - - - classif_id: BaggingClassifier()
# - - - - - - - - accuracy: 0.8193548387096774
# - - - - - - - - std_dev: 0.01706936329719095
# - - - - - - - - time_delta: 0.08305883407592773
# - - - - classif_id: ExtraTreesClassifier()
# - - - - - - - - accuracy: 0.8451612903225806
# - - - - - - - - std_dev: 0.03592106040535501
# - - - - - - - - time_delta: 0.39743828773498535
# - - - - classif_id: GradientBoostingClassifier()
# - - - - - - - - accuracy: 0.8193548387096774
# - - - - - - - - std_dev: 0.02234904267830815
# - - - - - - - - time_delta: 0.30435729026794434
# - - - - classif_id: HistGradientBoostingClassifier()
# - - - - - - - - accuracy: 0.8344086021505376
# - - - - - - - - std_dev: 0.016236203086603746
# - - - - - - - - time_delta: 0.2860255241394043
# - - - - classif_id: RandomForestClassifier()
# - - - - - - - - accuracy: 0.8365591397849462
# - - - - - - - - std_dev: 0.026073883124692783
# - - - - - - - - time_delta: 0.5220417976379395
# - - - - classif_id: GaussianProcessClassifier()
# - - - - - - - - accuracy: 0.8193548387096774
# - - - - - - - - std_dev: 0.045161290322580656
# - - - - - - - - time_delta: 0.14105987548828125
# - - - - classif_id: LogisticRegression()
# - - - - - - - - accuracy: 0.8516129032258064
# - - - - - - - - std_dev: 0.03592106040535501
# - - - - - - - - time_delta: 0.09314942359924316
# - - - - classif_id: LogisticRegressionCV()
# - - - - - - - - accuracy: 0.8451612903225806
# - - - - - - - - std_dev: 0.023261621132025734
# - - - - - - - - time_delta: 0.5929734706878662
# - - - - classif_id: PassiveAggressiveClassifier()
# - - - - - - - - accuracy: 0.7311827956989246
# - - - - - - - - std_dev: 0.07777695191408654
# - - - - - - - - time_delta: 0.017426490783691406
# - - - - classif_id: Perceptron()
# - - - - - - - - accuracy: 0.8064516129032259
# - - - - - - - - std_dev: 0.03413872659438184
# - - - - - - - - time_delta: 0.01948261260986328
# - - - - classif_id: RidgeClassifier()
# - - - - - - - - accuracy: 0.8623655913978494
# - - - - - - - - std_dev: 0.0324724061732075
# - - - - - - - - time_delta: 0.022588014602661133
# - - - - classif_id: RidgeClassifierCV()
# - - - - - - - - accuracy: 0.8623655913978494
# - - - - - - - - std_dev: 0.0324724061732075
# - - - - - - - - time_delta: 0.021556854248046875
# - - - - classif_id: SGDClassifier()
# - - - - - - - - accuracy: 0.7892473118279569
# - - - - - - - - std_dev: 0.0244254122400012
# - - - - - - - - time_delta: 0.019913196563720703
# - - - - classif_id: BayesianGaussianMixture()
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.03759431838989258
# - - - - classif_id: GaussianMixture()
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.038155555725097656
# - - - - classif_id: BernoulliNB()
# - - - - - - - - accuracy: 0.7290322580645161
# - - - - - - - - std_dev: 0.028121928668004354
# - - - - - - - - time_delta: 0.033620357513427734
# - - - - classif_id: GaussianNB()
# - - - - - - - - accuracy: 0.7806451612903226
# - - - - - - - - std_dev: 0.023261621132025734
# - - - - - - - - time_delta: 0.03679227828979492
# - - - - classif_id: MultinomialNB()
# - exception - classif_id: MultinomialNB()
#     type: <class 'ValueError'>
#     err: Negative values in data passed to MultinomialNB (input X)
# - exception - classif_id: MultinomialNB()
#     type: <class 'ValueError'>
#     err: Negative values in data passed to MultinomialNB (input X)
# - exception - classif_id: MultinomialNB()
#     type: <class 'ValueError'>
#     err: Negative values in data passed to MultinomialNB (input X)
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.046568870544433594
# - - - - classif_id: KNeighborsClassifier()
# - - - - - - - - accuracy: 0.8408602150537634
# - - - - - - - - std_dev: 0.013430103222362136
# - - - - - - - - time_delta: 0.05536532402038574
# - - - - classif_id: NearestCentroid()
# - - - - - - - - accuracy: 0.7806451612903226
# - - - - - - - - std_dev: 0.03924362922773045
# - - - - - - - - time_delta: 0.02236795425415039
# - - - - classif_id: RadiusNeighborsClassifier()
# - exception - classif_id: RadiusNeighborsClassifier()
#     type: <class 'ValueError'>
#     err: No neighbors found for test samples array([  0,   1,   2,   3,   4,   5
# - exception - classif_id: RadiusNeighborsClassifier()
#     type: <class 'ValueError'>
#     err: No neighbors found for test samples array([  0,   1,   2,   3,   4,   5
# - exception - classif_id: RadiusNeighborsClassifier()
#     type: <class 'ValueError'>
#     err: No neighbors found for test samples array([  0,   1,   2,   3,   4,   5
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.04010772705078125
# - - - - classif_id: MLPClassifier()
# - - - - - - - - accuracy: 0.8043010752688172
# - - - - - - - - std_dev: 0.026073883124692783
# - - - - - - - - time_delta: 0.6703944206237793
# - - - - classif_id: LabelPropagation()
# - - - - - - - - accuracy: 0.7096774193548386
# - - - - - - - - std_dev: 0.045161290322580636
# - - - - - - - - time_delta: 0.041449785232543945
# - - - - classif_id: LabelSpreading()
# - - - - - - - - accuracy: 0.7096774193548386
# - - - - - - - - std_dev: 0.045161290322580636
# - - - - - - - - time_delta: 0.03641223907470703
# - - - - classif_id: LinearSVC()
# - - - - - - - - accuracy: 0.7204301075268816
# - - - - - - - - std_dev: 0.06266151520143425
# - - - - - - - - time_delta: 0.041648149490356445
# - - - - classif_id: NuSVC()
# - - - - - - - - accuracy: 0.8322580645161292
# - - - - - - - - std_dev: 0.01706936329719095
# - - - - - - - - time_delta: 0.023736953735351562
# - - - - classif_id: OneClassSVM()
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.02085113525390625
# - - - - classif_id: SVC()
# - - - - - - - - accuracy: 0.8322580645161292
# - - - - - - - - std_dev: 0.02326162113202575
# - - - - - - - - time_delta: 0.0216524600982666
# - - - - classif_id: DecisionTreeClassifier()
# - - - - - - - - accuracy: 0.8064516129032259
# - - - - - - - - std_dev: 0.04469808535661617
# - - - - - - - - time_delta: 0.02265453338623047
# - - - - classif_id: ExtraTreeClassifier()
# - - - - - - - - accuracy: 0.8064516129032259
# - - - - - - - - std_dev: 0.028121928668004354
# - - - - - - - - time_delta: 0.020709753036499023
# - - - - classif_id: XGBClassifierWrap({})
# - - - - - - - - accuracy: 0.8301075268817204
# - - - - - - - - std_dev: 0.022657319898608044
# - - - - - - - - time_delta: 0.1334681510925293
# - - - - classif_id: CatBoostClassifier
# - - - - - - - - accuracy: 0.8430107526881719
# - - - - - - - - std_dev: 0.020739033894608495
# - - - - - - - - time_delta: 4.213747262954712
# - - - - classif_id: DeodataDelangaClassifier({})
# - - - - - - - - accuracy: 0.7225806451612904
# - - - - - - - - std_dev: 0.056243857336008674
# - - - - - - - - time_delta: 0.21735525131225586
# - - - - classif_id: DeodelSecond({})
# - - - - - - - - accuracy: 0.7849462365591399
# - - - - - - - - std_dev: 0.05174713727103643
# - - - - - - - - time_delta: 1.0524721145629883
# - - - - classif_id: <<< Random Baseline >>>
# - - - - - - - - accuracy: 0.5806451612903226
# - - - - - - - - std_dev: 0.01290322580645159
# - - - - - - - - time_delta: 0.02559638023376465
# - - - - - - - - - - - -
# - - - - - - - - - - - -
# - - - - crt_classif: CalibratedClassifierCV()
# - - - - rank_score_avg: 0.513157894736842
# - - - - rank_score_stdev: 0.060297048617839986
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LinearDiscriminantAnalysis()
# - - - - rank_score_avg: 0.9122807017543859
# - - - - rank_score_stdev: 0.03311330892662608
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: QuadraticDiscriminantAnalysis()
# - - - - rank_score_avg: 0.7017543859649124
# - - - - rank_score_stdev: 0.1880858038806278
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: AdaBoostClassifier()
# - - - - rank_score_avg: 0.4473684210526316
# - - - - rank_score_stdev: 0.1027664431040349
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BaggingClassifier()
# - - - - rank_score_avg: 0.6008771929824561
# - - - - rank_score_stdev: 0.1541964546600609
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreesClassifier()
# - - - - rank_score_avg: 0.8026315789473685
# - - - - rank_score_stdev: 0.17702136904044352
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GradientBoostingClassifier()
# - - - - rank_score_avg: 0.5921052631578947
# - - - - rank_score_stdev: 0.09210526315789475
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: HistGradientBoostingClassifier()
# - - - - rank_score_avg: 0.7543859649122807
# - - - - rank_score_stdev: 0.1250576967489759
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RandomForestClassifier()
# - - - - rank_score_avg: 0.763157894736842
# - - - - rank_score_stdev: 0.1255183159759139
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianProcessClassifier()
# - - - - rank_score_avg: 0.5877192982456141
# - - - - rank_score_stdev: 0.19531091296677477
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LogisticRegression()
# - - - - rank_score_avg: 0.868421052631579
# - - - - rank_score_stdev: 0.08003634908287133
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LogisticRegressionCV()
# - - - - rank_score_avg: 0.8552631578947368
# - - - - rank_score_stdev: 0.045580284409707246
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: PassiveAggressiveClassifier()
# - - - - rank_score_avg: 0.2675438596491228
# - - - - rank_score_stdev: 0.13695171049119292
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: Perceptron()
# - - - - rank_score_avg: 0.49122807017543857
# - - - - rank_score_stdev: 0.13245323570650439
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RidgeClassifier()
# - - - - rank_score_avg: 0.9605263157894737
# - - - - rank_score_stdev: 0.045580284409707246
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RidgeClassifierCV()
# - - - - rank_score_avg: 0.9605263157894737
# - - - - rank_score_stdev: 0.045580284409707246
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SGDClassifier()
# - - - - rank_score_avg: 0.4517543859649123
# - - - - rank_score_stdev: 0.14789223947445057
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BayesianGaussianMixture()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianMixture()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BernoulliNB()
# - - - - rank_score_avg: 0.25877192982456143
# - - - - rank_score_stdev: 0.0273903420982386
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianNB()
# - - - - rank_score_avg: 0.37280701754385964
# - - - - rank_score_stdev: 0.03311330892662609
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: MultinomialNB()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: KNeighborsClassifier()
# - - - - rank_score_avg: 0.8201754385964912
# - - - - rank_score_stdev: 0.11034864583692211
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NearestCentroid()
# - - - - rank_score_avg: 0.3991228070175439
# - - - - rank_score_stdev: 0.08039606482378667
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RadiusNeighborsClassifier()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: MLPClassifier()
# - - - - rank_score_avg: 0.45175438596491224
# - - - - rank_score_stdev: 0.03798357034142274
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelPropagation()
# - - - - rank_score_avg: 0.20614035087719298
# - - - - rank_score_stdev: 0.015193428136569098
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelSpreading()
# - - - - rank_score_avg: 0.20614035087719298
# - - - - rank_score_stdev: 0.015193428136569098
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LinearSVC()
# - - - - rank_score_avg: 0.20175438596491227
# - - - - rank_score_stdev: 0.0759671406828455
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NuSVC()
# - - - - rank_score_avg: 0.706140350877193
# - - - - rank_score_stdev: 0.0724680335169224
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: OneClassSVM()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SVC()
# - - - - rank_score_avg: 0.706140350877193
# - - - - rank_score_stdev: 0.04620900768795059
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DecisionTreeClassifier()
# - - - - rank_score_avg: 0.5438596491228069
# - - - - rank_score_stdev: 0.27008428628667813
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreeClassifier()
# - - - - rank_score_avg: 0.47807017543859653
# - - - - rank_score_stdev: 0.11793271631358557
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: XGBClassifierWrap({})
# - - - - rank_score_avg: 0.6798245614035088
# - - - - rank_score_stdev: 0.06218178455595538
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: CatBoostClassifier
# - - - - rank_score_avg: 0.8464912280701754
# - - - - rank_score_stdev: 0.08459342772800839
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodataDelangaClassifier({})
# - - - - rank_score_avg: 0.24561403508771928
# - - - - rank_score_stdev: 0.02009901620594666
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodelSecond({})
# - - - - rank_score_avg: 0.4517543859649123
# - - - - rank_score_stdev: 0.22419961261635188
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: <<< Random Baseline >>>
# - - - - rank_score_avg: 0.13157894736842105
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# time_stamp: 2024-03-04 04:28:27
#
# --------------------------------------------------------------------------------
# - - - - dataset name: dset-vertebral-datos_orixinais-column_2C_weka.csv
#
# rank score avg      stdev  accuracy avg        xpt  classifier
# --------------------------------------------------------------------------------
# 0.9605263157894737  0.045> 0.8623655913978494  0    RidgeClassifierCV()
# 0.9605263157894737  0.045> 0.8623655913978494  0    RidgeClassifier()
# 0.9122807017543859  0.033> 0.8559139784946237  0    LinearDiscriminantAnalysis()
# 0.868421052631579   0.080> 0.8516129032258064  0    LogisticRegression()
# 0.8552631578947368  0.045> 0.8451612903225806  0    LogisticRegressionCV()
# 0.8464912280701754  0.084> 0.8430107526881719  0    CatBoostClassifier
# 0.8201754385964912  0.110> 0.8408602150537634  0    KNeighborsClassifier()
# 0.8026315789473685  0.177> 0.8451612903225806  0    ExtraTreesClassifier()
# 0.763157894736842   0.125> 0.8365591397849462  0    RandomForestClassifier()
# 0.7543859649122807  0.125> 0.8344086021505376  0    HistGradientBoostingClassifier()
# 0.706140350877193   0.046> 0.8322580645161292  0    SVC()
# 0.706140350877193   0.072> 0.8322580645161292  0    NuSVC()
# 0.7017543859649124  0.188> 0.8344086021505376  0    QuadraticDiscriminantAnalysis()
# 0.6798245614035088  0.062> 0.8301075268817204  0    XGBClassifierWrap({})
# 0.6008771929824561  0.154> 0.8193548387096774  0    BaggingClassifier()
# 0.5921052631578947  0.092> 0.8193548387096774  0    GradientBoostingClassifier()
# 0.5877192982456141  0.195> 0.8193548387096774  0    GaussianProcessClassifier()
# 0.5438596491228069  0.270> 0.8064516129032259  0    DecisionTreeClassifier()
# 0.513157894736842   0.060> 0.8064516129032259  0    CalibratedClassifierCV()
# 0.49122807017543857 0.132> 0.8064516129032259  0    Perceptron()
# 0.47807017543859653 0.117> 0.8064516129032259  0    ExtraTreeClassifier()
# 0.4517543859649123  0.224> 0.7849462365591399  0    DeodelSecond({})
# 0.4517543859649123  0.147> 0.7892473118279569  0    SGDClassifier()
# 0.45175438596491224 0.037> 0.8043010752688172  0    MLPClassifier()
# 0.4473684210526316  0.102> 0.7913978494623656  0    AdaBoostClassifier()
# 0.3991228070175439  0.080> 0.7806451612903226  0    NearestCentroid()
# 0.37280701754385964 0.033> 0.7806451612903226  0    GaussianNB()
# 0.2675438596491228  0.136> 0.7311827956989246  0    PassiveAggressiveClassifier()
# 0.25877192982456143 0.027> 0.7290322580645161  0    BernoulliNB()
# 0.24561403508771928 0.020> 0.7225806451612904  0    DeodataDelangaClassifier({})
# 0.20614035087719298 0.015> 0.7096774193548386  0    LabelSpreading()
# 0.20614035087719298 0.015> 0.7096774193548386  0    LabelPropagation()
# 0.20175438596491227 0.075> 0.7204301075268816  0    LinearSVC()
# 0.13157894736842105 0.0    0.5806451612903226  0    <<< Random Baseline >>>
# 0.05263157894736842 0.0    0.0                 0    OneClassSVM()
# 0.05263157894736842 0.0    0.0                 3    RadiusNeighborsClassifier()
# 0.05263157894736842 0.0    0.0                 3    MultinomialNB()
# 0.05263157894736842 0.0    0.0                 0    GaussianMixture()
# 0.05263157894736842 0.0    0.0                 0    BayesianGaussianMixture()
# --------------------------------------------------------------------------------
#
# - - - - - - - - -
# - - - - dataset: dset-vertebral-datos_orixinais-column_3C_weka.csv
# - - - - - - - - -
# - - - data processing - retrieved csv
# - - - - - - input_no_row: 310
# - - - - - - input_no_col: 7
# - - - - - - input_targ_idx: -1
# - - - - - - insput_start_row: 0
# - - - - - - - - -
# - - - data sample:
#     [63.0278175, 22.55258597, 39.60911701, 40.47523153, 98.67291675, -0.254399986, 'Hernia']
#     [39.05695098, 10.06099147, 25.01537822, 28.99595951, 114.4054254, 4.564258645, 'Hernia']
#     [68.83202098, 22.21848205, 50.09219357, 46.61353893, 105.9851355, -3.530317314, 'Hernia']
#     [69.29700807, 24.65287791, 44.31123813, 44.64413017, 101.8684951, 11.21152344, 'Hernia']
#     [49.71285934, 9.652074879, 28.317406, 40.06078446, 108.1687249, 7.918500615, 'Hernia']
#     ...
#     [47.90356517, 13.61668819, 36, 34.28687698, 117.4490622, -4.245395422, 'Normal']
#     [53.93674778, 20.72149628, 29.22053381, 33.21525149, 114.365845, -0.421010392, 'Normal']
#     [61.44659663, 22.6949683, 46.17034732, 38.75162833, 125.6707246, -2.707879517, 'Normal']
#     [45.25279209, 8.693157364, 41.5831264, 36.55963472, 118.5458418, 0.214750167, 'Normal']
#     [33.84164075, 5.073991409, 36.64123294, 28.76764934, 123.9452436, -0.199249089, 'Normal']
# - - - - - - - - -
#
# - - - data processing - target extracted
# - - - data processing - one-hot encoded
# - - - - - - onehot_no_row: 310
# - - - - - - onehot_no_col: 6
# - - - data processing - size limitation
# - - - - - - proc_no_row: 310
# - - - - - - proc_no_col: 6
# - - - data row number unchanged
# - - - data col number unchanged
# - - - data processing - finished
# - - - - - - proc_no_row: 310
# - - - - - - proc_no_col: 6
# - - - data sample:
#     [63.0278175, 22.55258597, 39.60911701, 40.47523153, 98.67291675, -0.254399986]
#     [39.05695098, 10.06099147, 25.01537822, 28.99595951, 114.4054254, 4.564258645]
#     [68.83202098, 22.21848205, 50.09219357, 46.61353893, 105.9851355, -3.530317314]
#     [69.29700807, 24.65287791, 44.31123813, 44.64413017, 101.8684951, 11.21152344]
#     [49.71285934, 9.652074879, 28.317406, 40.06078446, 108.1687249, 7.918500615]
#     ...
#     [47.90356517, 13.61668819, 36, 34.28687698, 117.4490622, -4.245395422]
#     [53.93674778, 20.72149628, 29.22053381, 33.21525149, 114.365845, -0.421010392]
#     [61.44659663, 22.6949683, 46.17034732, 38.75162833, 125.6707246, -2.707879517]
#     [45.25279209, 8.693157364, 41.5831264, 36.55963472, 118.5458418, 0.214750167]
#     [33.84164075, 5.073991409, 36.64123294, 28.76764934, 123.9452436, -0.199249089]
#
# --------------------------------------------------------------------------------
# time_stamp: 2024-03-04 04:28:27
# - - - - - - - - - - - -
# - - - - classif_id: CalibratedClassifierCV()
# - - - - - - - - accuracy: 0.8107526881720429
# - - - - - - - - std_dev: 0.03247240617320756
# - - - - - - - - time_delta: 0.3951573371887207
# - - - - classif_id: LinearDiscriminantAnalysis()
# - - - - - - - - accuracy: 0.8150537634408602
# - - - - - - - - std_dev: 0.024425412240001176
# - - - - - - - - time_delta: 0.02237987518310547
# - - - - classif_id: QuadraticDiscriminantAnalysis()
# - - - - - - - - accuracy: 0.8322580645161289
# - - - - - - - - std_dev: 0.017069363297190887
# - - - - - - - - time_delta: 0.019677400588989258
# - - - - classif_id: AdaBoostClassifier()
# - - - - - - - - accuracy: 0.5870967741935483
# - - - - - - - - std_dev: 0.14237468703686393
# - - - - - - - - time_delta: 0.4298222064971924
# - - - - classif_id: BaggingClassifier()
# - - - - - - - - accuracy: 0.8344086021505377
# - - - - - - - - std_dev: 0.009855001494528714
# - - - - - - - - time_delta: 0.1149454116821289
# - - - - classif_id: ExtraTreesClassifier()
# - - - - - - - - accuracy: 0.8215053763440859
# - - - - - - - - std_dev: 0.024425412240001176
# - - - - - - - - time_delta: 0.6045064926147461
# - - - - classif_id: GradientBoostingClassifier()
# - - - - - - - - accuracy: 0.8215053763440862
# - - - - - - - - std_dev: 0.03553271320829746
# - - - - - - - - time_delta: 1.4936680793762207
# - - - - classif_id: HistGradientBoostingClassifier()
# - - - - - - - - accuracy: 0.8172043010752689
# - - - - - - - - std_dev: 0.02607388312469278
# - - - - - - - - time_delta: 0.810532808303833
# - - - - classif_id: RandomForestClassifier()
# - - - - - - - - accuracy: 0.8408602150537634
# - - - - - - - - std_dev: 0.02265731989860804
# - - - - - - - - time_delta: 0.5230517387390137
# - - - - classif_id: GaussianProcessClassifier()
# - - - - - - - - accuracy: 0.6279569892473118
# - - - - - - - - std_dev: 0.06462356645727621
# - - - - - - - - time_delta: 0.38936662673950195
# - - - - classif_id: LogisticRegression()
# - - - - - - - - accuracy: 0.8365591397849462
# - - - - - - - - std_dev: 0.02607388312469278
# - - - - - - - - time_delta: 0.14045310020446777
# - - - - classif_id: LogisticRegressionCV()
# - - - - - - - - accuracy: 0.8516129032258064
# - - - - - - - - std_dev: 0.006451612903225767
# - - - - - - - - time_delta: 1.9285144805908203
# - - - - classif_id: PassiveAggressiveClassifier()
# - - - - - - - - accuracy: 0.7806451612903226
# - - - - - - - - std_dev: 0.04469808535661617
# - - - - - - - - time_delta: 0.0208280086517334
# - - - - classif_id: Perceptron()
# - - - - - - - - accuracy: 0.7634408602150536
# - - - - - - - - std_dev: 0.0268602064447243
# - - - - - - - - time_delta: 0.026932477951049805
# - - - - classif_id: RidgeClassifier()
# - - - - - - - - accuracy: 0.8344086021505376
# - - - - - - - - std_dev: 0.0244254122400012
# - - - - - - - - time_delta: 0.021332502365112305
# - - - - classif_id: RidgeClassifierCV()
# - - - - - - - - accuracy: 0.8344086021505376
# - - - - - - - - std_dev: 0.0244254122400012
# - - - - - - - - time_delta: 0.027587890625
# - - - - classif_id: SGDClassifier()
# - - - - - - - - accuracy: 0.7892473118279569
# - - - - - - - - std_dev: 0.03182505072462097
# - - - - - - - - time_delta: 0.023883342742919922
# - - - - classif_id: BayesianGaussianMixture()
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.054723501205444336
# - - - - classif_id: GaussianMixture()
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.05361676216125488
# - - - - classif_id: BernoulliNB()
# - - - - - - - - accuracy: 0.6086021505376344
# - - - - - - - - std_dev: 0.02979872357107747
# - - - - - - - - time_delta: 0.049082279205322266
# - - - - classif_id: GaussianNB()
# - - - - - - - - accuracy: 0.8258064516129032
# - - - - - - - - std_dev: 0.006451612903225823
# - - - - - - - - time_delta: 0.04465150833129883
# - - - - classif_id: MultinomialNB()
# - exception - classif_id: MultinomialNB()
#     type: <class 'ValueError'>
#     err: Negative values in data passed to MultinomialNB (input X)
# - exception - classif_id: MultinomialNB()
#     type: <class 'ValueError'>
#     err: Negative values in data passed to MultinomialNB (input X)
# - exception - classif_id: MultinomialNB()
#     type: <class 'ValueError'>
#     err: Negative values in data passed to MultinomialNB (input X)
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.023793935775756836
# - - - - classif_id: KNeighborsClassifier()
# - - - - - - - - accuracy: 0.8279569892473119
# - - - - - - - - std_dev: 0.013430103222362181
# - - - - - - - - time_delta: 0.05097532272338867
# - - - - classif_id: NearestCentroid()
# - - - - - - - - accuracy: 0.7978494623655914
# - - - - - - - - std_dev: 0.019710002989057368
# - - - - - - - - time_delta: 0.02265191078186035
# - - - - classif_id: RadiusNeighborsClassifier()
# - exception - classif_id: RadiusNeighborsClassifier()
#     type: <class 'ValueError'>
#     err: No neighbors found for test samples array([  0,   1,   2,   3,   4,   5
# - exception - classif_id: RadiusNeighborsClassifier()
#     type: <class 'ValueError'>
#     err: No neighbors found for test samples array([  0,   1,   2,   3,   4,   5
# - exception - classif_id: RadiusNeighborsClassifier()
#     type: <class 'ValueError'>
#     err: No neighbors found for test samples array([  0,   1,   2,   3,   4,   5
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.03159141540527344
# - - - - classif_id: MLPClassifier()
# - - - - - - - - accuracy: 0.7956989247311829
# - - - - - - - - std_dev: 0.016236203086603746
# - - - - - - - - time_delta: 0.47091054916381836
# - - - - classif_id: LabelPropagation()
# - - - - - - - - accuracy: 0.23010752688172043
# - - - - - - - - std_dev: 0.018624202231923397
# - - - - - - - - time_delta: 0.023656368255615234
# - - - - classif_id: LabelSpreading()
# - - - - - - - - accuracy: 0.23010752688172043
# - - - - - - - - std_dev: 0.018624202231923397
# - - - - - - - - time_delta: 0.021648168563842773
# - - - - classif_id: LinearSVC()
# - - - - - - - - accuracy: 0.7655913978494624
# - - - - - - - - std_dev: 0.03247240617320756
# - - - - - - - - time_delta: 0.047774553298950195
# - - - - classif_id: NuSVC()
# - - - - - - - - accuracy: 0.8516129032258064
# - - - - - - - - std_dev: 0.03352356401746216
# - - - - - - - - time_delta: 0.02599644660949707
# - - - - classif_id: OneClassSVM()
# - - - - - - - - accuracy: 0.0
# - - - - - - - - std_dev: 0.0
# - - - - - - - - time_delta: 0.024755477905273438
# - - - - classif_id: SVC()
# - - - - - - - - accuracy: 0.8236559139784947
# - - - - - - - - std_dev: 0.0268602064447243
# - - - - - - - - time_delta: 0.02675604820251465
# - - - - classif_id: DecisionTreeClassifier()
# - - - - - - - - accuracy: 0.7870967741935484
# - - - - - - - - std_dev: 0.02326162113202575
# - - - - - - - - time_delta: 0.01902294158935547
# - - - - classif_id: ExtraTreeClassifier()
# - - - - - - - - accuracy: 0.7096774193548386
# - - - - - - - - std_dev: 0.05120808989157268
# - - - - - - - - time_delta: 0.02253246307373047
# - - - - classif_id: XGBClassifierWrap({})
# - - - - - - - - accuracy: 0.8236559139784946
# - - - - - - - - std_dev: 0.026073883124692734
# - - - - - - - - time_delta: 0.21603059768676758
# - - - - classif_id: CatBoostClassifier
# - - - - - - - - accuracy: 0.8279569892473119
# - - - - - - - - std_dev: 0.019710002989057427
# - - - - - - - - time_delta: 8.442546844482422
# - - - - classif_id: DeodataDelangaClassifier({})
# - - - - - - - - accuracy: 0.6666666666666666
# - - - - - - - - std_dev: 0.07697002222870225
# - - - - - - - - time_delta: 0.23044562339782715
# - - - - classif_id: DeodelSecond({})
# - - - - - - - - accuracy: 0.7483870967741936
# - - - - - - - - std_dev: 0.06154446460754487
# - - - - - - - - time_delta: 0.9732444286346436
# - - - - classif_id: <<< Random Baseline >>>
# - - - - - - - - accuracy: 0.4086021505376343
# - - - - - - - - std_dev: 0.01971000298905737
# - - - - - - - - time_delta: 0.027698993682861328
# - - - - - - - - - - - -
# - - - - - - - - - - - -
# - - - - crt_classif: CalibratedClassifierCV()
# - - - - rank_score_avg: 0.6271929824561404
# - - - - rank_score_stdev: 0.26621036676304416
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LinearDiscriminantAnalysis()
# - - - - rank_score_avg: 0.6140350877192983
# - - - - rank_score_stdev: 0.09334998532365242
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: QuadraticDiscriminantAnalysis()
# - - - - rank_score_avg: 0.8026315789473685
# - - - - rank_score_stdev: 0.19471906035458872
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: AdaBoostClassifier()
# - - - - rank_score_avg: 0.23684210526315788
# - - - - rank_score_stdev: 0.045580284409707315
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BaggingClassifier()
# - - - - rank_score_avg: 0.75
# - - - - rank_score_stdev: 0.1679887544053119
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreesClassifier()
# - - - - rank_score_avg: 0.7017543859649122
# - - - - rank_score_stdev: 0.11190658615941294
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GradientBoostingClassifier()
# - - - - rank_score_avg: 0.706140350877193
# - - - - rank_score_stdev: 0.21311457216239196
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: HistGradientBoostingClassifier()
# - - - - rank_score_avg: 0.6403508771929824
# - - - - rank_score_stdev: 0.11034864583692211
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RandomForestClassifier()
# - - - - rank_score_avg: 0.881578947368421
# - - - - rank_score_stdev: 0.08217102629471579
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianProcessClassifier()
# - - - - rank_score_avg: 0.25
# - - - - rank_score_stdev: 0.013157894736842105
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LogisticRegression()
# - - - - rank_score_avg: 0.7982456140350878
# - - - - rank_score_stdev: 0.27168211694646627
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LogisticRegressionCV()
# - - - - rank_score_avg: 0.9342105263157895
# - - - - rank_score_stdev: 0.08003634908287133
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: PassiveAggressiveClassifier()
# - - - - rank_score_avg: 0.5131578947368421
# - - - - rank_score_stdev: 0.1986798535597566
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: Perceptron()
# - - - - rank_score_avg: 0.40350877192982454
# - - - - rank_score_stdev: 0.08459342772800837
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RidgeClassifier()
# - - - - rank_score_avg: 0.8289473684210527
# - - - - rank_score_stdev: 0.09933992677987825
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RidgeClassifierCV()
# - - - - rank_score_avg: 0.8289473684210527
# - - - - rank_score_stdev: 0.09933992677987825
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SGDClassifier()
# - - - - rank_score_avg: 0.4824561403508772
# - - - - rank_score_stdev: 0.1063539969559837
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BayesianGaussianMixture()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianMixture()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BernoulliNB()
# - - - - rank_score_avg: 0.23684210526315788
# - - - - rank_score_stdev: 0.02631578947368421
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianNB()
# - - - - rank_score_avg: 0.7236842105263158
# - - - - rank_score_stdev: 0.1255183159759139
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: MultinomialNB()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: KNeighborsClassifier()
# - - - - rank_score_avg: 0.7587719298245614
# - - - - rank_score_stdev: 0.046209007687950644
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NearestCentroid()
# - - - - rank_score_avg: 0.4780701754385965
# - - - - rank_score_stdev: 0.09334998532365248
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RadiusNeighborsClassifier()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: MLPClassifier()
# - - - - rank_score_avg: 0.5350877192982456
# - - - - rank_score_stdev: 0.06752107157166952
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelPropagation()
# - - - - rank_score_avg: 0.14473684210526316
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelSpreading()
# - - - - rank_score_avg: 0.14473684210526316
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LinearSVC()
# - - - - rank_score_avg: 0.39473684210526316
# - - - - rank_score_stdev: 0.02631578947368421
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NuSVC()
# - - - - rank_score_avg: 0.9342105263157895
# - - - - rank_score_stdev: 0.11395071102426821
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: OneClassSVM()
# - - - - rank_score_avg: 0.05263157894736842
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SVC()
# - - - - rank_score_avg: 0.7192982456140351
# - - - - rank_score_stdev: 0.1394571324174092
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DecisionTreeClassifier()
# - - - - rank_score_avg: 0.49122807017543857
# - - - - rank_score_stdev: 0.09875728288769912
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreeClassifier()
# - - - - rank_score_avg: 0.32456140350877194
# - - - - rank_score_stdev: 0.04019803241189332
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: XGBClassifierWrap({})
# - - - - rank_score_avg: 0.7236842105263158
# - - - - rank_score_stdev: 0.1865453536678661
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: CatBoostClassifier
# - - - - rank_score_avg: 0.7587719298245614
# - - - - rank_score_stdev: 0.07246803351692237
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodataDelangaClassifier({})
# - - - - rank_score_avg: 0.2894736842105263
# - - - - rank_score_stdev: 0.03947368421052633
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodelSecond({})
# - - - - rank_score_avg: 0.39473684210526316
# - - - - rank_score_stdev: 0.11470786693528087
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: <<< Random Baseline >>>
# - - - - rank_score_avg: 0.18421052631578946
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# time_stamp: 2024-03-04 04:28:45
#
# --------------------------------------------------------------------------------
# - - - - dataset name: dset-vertebral-datos_orixinais-column_3C_weka.csv
#
# rank score avg      stdev  accuracy avg        xpt  classifier
# --------------------------------------------------------------------------------
# 0.9342105263157895  0.113> 0.8516129032258064  0    NuSVC()
# 0.9342105263157895  0.080> 0.8516129032258064  0    LogisticRegressionCV()
# 0.881578947368421   0.082> 0.8408602150537634  0    RandomForestClassifier()
# 0.8289473684210527  0.099> 0.8344086021505376  0    RidgeClassifierCV()
# 0.8289473684210527  0.099> 0.8344086021505376  0    RidgeClassifier()
# 0.8026315789473685  0.194> 0.8322580645161289  0    QuadraticDiscriminantAnalysis()
# 0.7982456140350878  0.271> 0.8365591397849462  0    LogisticRegression()
# 0.7587719298245614  0.072> 0.8279569892473119  0    CatBoostClassifier
# 0.7587719298245614  0.046> 0.8279569892473119  0    KNeighborsClassifier()
# 0.75                0.167> 0.8344086021505377  0    BaggingClassifier()
# 0.7236842105263158  0.186> 0.8236559139784946  0    XGBClassifierWrap({})
# 0.7236842105263158  0.125> 0.8258064516129032  0    GaussianNB()
# 0.7192982456140351  0.139> 0.8236559139784947  0    SVC()
# 0.706140350877193   0.213> 0.8215053763440862  0    GradientBoostingClassifier()
# 0.7017543859649122  0.111> 0.8215053763440859  0    ExtraTreesClassifier()
# 0.6403508771929824  0.110> 0.8172043010752689  0    HistGradientBoostingClassifier()
# 0.6271929824561404  0.266> 0.8107526881720429  0    CalibratedClassifierCV()
# 0.6140350877192983  0.093> 0.8150537634408602  0    LinearDiscriminantAnalysis()
# 0.5350877192982456  0.067> 0.7956989247311829  0    MLPClassifier()
# 0.5131578947368421  0.198> 0.7806451612903226  0    PassiveAggressiveClassifier()
# 0.49122807017543857 0.098> 0.7870967741935484  0    DecisionTreeClassifier()
# 0.4824561403508772  0.106> 0.7892473118279569  0    SGDClassifier()
# 0.4780701754385965  0.093> 0.7978494623655914  0    NearestCentroid()
# 0.40350877192982454 0.084> 0.7634408602150536  0    Perceptron()
# 0.39473684210526316 0.114> 0.7483870967741936  0    DeodelSecond({})
# 0.39473684210526316 0.026> 0.7655913978494624  0    LinearSVC()
# 0.32456140350877194 0.040> 0.7096774193548386  0    ExtraTreeClassifier()
# 0.2894736842105263  0.039> 0.6666666666666666  0    DeodataDelangaClassifier({})
# 0.25                0.013> 0.6279569892473118  0    GaussianProcessClassifier()
# 0.23684210526315788 0.026> 0.6086021505376344  0    BernoulliNB()
# 0.23684210526315788 0.045> 0.5870967741935483  0    AdaBoostClassifier()
# 0.18421052631578946 0.0    0.4086021505376343  0    <<< Random Baseline >>>
# 0.14473684210526316 0.0    0.23010752688172043 0    LabelSpreading()
# 0.14473684210526316 0.0    0.23010752688172043 0    LabelPropagation()
# 0.05263157894736842 0.0    0.0                 0    OneClassSVM()
# 0.05263157894736842 0.0    0.0                 3    RadiusNeighborsClassifier()
# 0.05263157894736842 0.0    0.0                 3    MultinomialNB()
# 0.05263157894736842 0.0    0.0                 0    GaussianMixture()
# 0.05263157894736842 0.0    0.0                 0    BayesianGaussianMixture()
# --------------------------------------------------------------------------------
#
# - - - - - - - - -
# - - - - dataset: dset-wall-following.csv
# - - - - - - - - -
# - - - data processing - retrieved csv
# - - - - - - input_no_row: 5455
# - - - - - - input_no_col: 25
# - - - - - - input_targ_idx: -1
# - - - - - - insput_start_row: 1
# - - - - - - - - -
# - - - data sample:
#     [-1.28751, -1.29706, 0.910391, 0.650313, 1.52435] ... [-0.659113, -0.848792, -0.861084, -0.999155, 1]
#     [-1.28751, -1.29706, 0.910391, 0.635802, 1.52435] ... [-0.659113, -0.848792, -0.858761, -0.999155, 1]
#     [-1.28876, -1.29493, 0.910391, 0.633511, 1.52435] ... [-0.659113, -0.848792, -0.86031, -0.999155, 1]
#     [-1.28751, -1.29706, 0.911192, 0.635802, 1.52435] ... [-0.659113, -0.848792, -0.862633, -0.999155, 1]
#     [-1.28627, -1.29706, 0.911192, 0.635802, 1.52435] ... [-0.659113, -0.848792, -0.86031, -0.998286, 1]
#     ...
#     [-0.699572, 1.89552, 1.2086, -0.00878384, -0.140792] ... [0.0327652, 2.05001, 2.66751, -0.0143489, 0]
#     [-0.679642, 1.89552, 1.22303, -0.00343775, -0.135565] ... [0.0474141, 2.05001, 2.66751, -0.428958, 2]
# ...
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BaggingClassifier()
# - - - - rank_score_avg: 0.9429824561403509
# - - - - rank_score_stdev: 0.053176998477991844
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreesClassifier()
# - - - - rank_score_avg: 0.8070175438596492
# - - - - rank_score_stdev: 0.12981270690305913
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GradientBoostingClassifier()
# - - - - rank_score_avg: 0.5745614035087719
# - - - - rank_score_stdev: 0.1676448671369859
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: HistGradientBoostingClassifier()
# - - - - rank_score_avg: 0.22807017543859648
# - - - - rank_score_stdev: 0.015193428136569098
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RandomForestClassifier()
# - - - - rank_score_avg: 0.8070175438596492
# - - - - rank_score_stdev: 0.12981270690305913
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianProcessClassifier()
# - - - - rank_score_avg: 0.6228070175438597
# - - - - rank_score_stdev: 0.06077371254627639
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LogisticRegression()
# - - - - rank_score_avg: 0.7456140350877193
# - - - - rank_score_stdev: 0.12981270690305913
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LogisticRegressionCV()
# - - - - rank_score_avg: 0.6666666666666667
# - - - - rank_score_stdev: 0.015193428136569083
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: PassiveAggressiveClassifier()
# - - - - rank_score_avg: 0.6666666666666667
# - - - - rank_score_stdev: 0.015193428136569083
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: Perceptron()
# - - - - rank_score_avg: 0.6666666666666667
# - - - - rank_score_stdev: 0.015193428136569083
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RidgeClassifier()
# - - - - rank_score_avg: 0.5350877192982456
# - - - - rank_score_stdev: 0.2127079939119674
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RidgeClassifierCV()
# - - - - rank_score_avg: 0.5219298245614035
# - - - - rank_score_stdev: 0.11939173323522985
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SGDClassifier()
# - - - - rank_score_avg: 0.5526315789473685
# - - - - rank_score_stdev: 0.1823211376388292
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BayesianGaussianMixture()
# - - - - rank_score_avg: 0.15789473684210525
# - - - - rank_score_stdev: 0.013157894736842105
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianMixture()
# - - - - rank_score_avg: 0.15789473684210525
# - - - - rank_score_stdev: 0.013157894736842105
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: BernoulliNB()
# - - - - rank_score_avg: 0.5394736842105263
# - - - - rank_score_stdev: 0.28495273457510156
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: GaussianNB()
# - - - - rank_score_avg: 0.36403508771929827
# - - - - rank_score_stdev: 0.02009901620594667
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: MultinomialNB()
# - - - - rank_score_avg: 0.02631578947368421
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: KNeighborsClassifier()
# - - - - rank_score_avg: 0.3157894736842105
# - - - - rank_score_stdev: 0.02631578947368421
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NearestCentroid()
# - - - - rank_score_avg: 0.368421052631579
# - - - - rank_score_stdev: 0.07326005740565819
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: RadiusNeighborsClassifier()
# - - - - rank_score_avg: 0.02631578947368421
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: MLPClassifier()
# - - - - rank_score_avg: 0.5614035087719298
# - - - - rank_score_stdev: 0.09241801537590126
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelPropagation()
# - - - - rank_score_avg: 0.5614035087719298
# - - - - rank_score_stdev: 0.09241801537590126
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LabelSpreading()
# - - - - rank_score_avg: 0.5614035087719298
# - - - - rank_score_stdev: 0.09241801537590126
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: LinearSVC()
# - - - - rank_score_avg: 0.793859649122807
# - - - - rank_score_stdev: 0.20983988971764359
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: NuSVC()
# - - - - rank_score_avg: 0.02631578947368421
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 3
# - - - - - - - - - - - -
# - - - - crt_classif: OneClassSVM()
# - - - - rank_score_avg: 0.07894736842105263
# - - - - rank_score_stdev: 0.0
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: SVC()
# - - - - rank_score_avg: 0.4298245614035088
# - - - - rank_score_stdev: 0.04620900768795059
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DecisionTreeClassifier()
# - - - - rank_score_avg: 0.8991228070175439
# - - - - rank_score_stdev: 0.03311330892662609
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: ExtraTreeClassifier()
# - - - - rank_score_avg: 0.6754385964912281
# - - - - rank_score_stdev: 0.25046125500472344
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: XGBClassifierWrap({})
# - - - - rank_score_avg: 0.8991228070175439
# - - - - rank_score_stdev: 0.03311330892662609
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: CatBoostClassifier
# - - - - rank_score_avg: 0.7236842105263158
# - - - - rank_score_stdev: 0.3094204214817065
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodataDelangaClassifier({})
# - - - - rank_score_avg: 0.8070175438596492
# - - - - rank_score_stdev: 0.12981270690305913
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: DeodelSecond({})
# - - - - rank_score_avg: 0.7280701754385965
# - - - - rank_score_stdev: 0.12154742509255279
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# - - - - crt_classif: <<< Random Baseline >>>
# - - - - rank_score_avg: 0.11403508771929824
# - - - - rank_score_stdev: 0.015193428136569098
# - - - - excpt_count: 0
# - - - - - - - - - - - -
# time_stamp: 2024-03-04 04:43:30
#
# --------------------------------------------------------------------------------
# - - - - dataset name: dset-zoo.csv
#
# rank score avg      stdev  accuracy avg        xpt  classifier
# --------------------------------------------------------------------------------
# 0.9429824561403509  0.053> 1.0                 0    BaggingClassifier()
# 0.8991228070175439  0.033> 0.9933333333333333  0    XGBClassifierWrap({})
# 0.8991228070175439  0.033> 0.9933333333333333  0    DecisionTreeClassifier()
# 0.8070175438596492  0.129> 0.9866666666666667  0    DeodataDelangaClassifier({})
# 0.8070175438596492  0.129> 0.9866666666666667  0    RandomForestClassifier()
# 0.8070175438596492  0.129> 0.9866666666666667  0    ExtraTreesClassifier()
# 0.793859649122807   0.209> 0.98                0    LinearSVC()
# 0.7456140350877193  0.129> 0.98                0    LogisticRegression()
# 0.7280701754385965  0.121> 0.98                0    DeodelSecond({})
# 0.7236842105263158  0.309> 0.9733333333333333  0    CatBoostClassifier
# 0.7149122807017544  0.288> 0.98                0    CalibratedClassifierCV()
# 0.6754385964912281  0.250> 0.9666666666666667  0    ExtraTreeClassifier()
# 0.6666666666666667  0.015> 0.9733333333333333  0    Perceptron()
# 0.6666666666666667  0.015> 0.9733333333333333  0    PassiveAggressiveClassifier()
# 0.6666666666666667  0.015> 0.9733333333333333  0    LogisticRegressionCV()
# 0.6228070175438597  0.060> 0.9666666666666667  0    GaussianProcessClassifier()
# 0.5745614035087719  0.167> 0.9666666666666667  0    GradientBoostingClassifier()
# 0.5614035087719298  0.092> 0.96                0    LabelSpreading()
# 0.5614035087719298  0.092> 0.96                0    LabelPropagation()
# 0.5614035087719298  0.092> 0.96                0    MLPClassifier()
# 0.5526315789473685  0.182> 0.9533333333333333  0    SGDClassifier()
# 0.5394736842105263  0.284> 0.96                0    BernoulliNB()
# 0.5350877192982456  0.212> 0.9466666666666667  0    RidgeClassifier()
# 0.5219298245614035  0.119> 0.9533333333333333  0    RidgeClassifierCV()
# 0.4298245614035088  0.046> 0.9466666666666667  0    SVC()
# 0.368421052631579   0.073> 0.9266666666666666  0    NearestCentroid()
# 0.36403508771929827 0.020> 0.9333333333333332  0    GaussianNB()
# 0.3157894736842105  0.026> 0.9066666666666667  0    KNeighborsClassifier()
# 0.24561403508771928 0.030> 0.7733333333333334  0    LinearDiscriminantAnalysis()
# 0.23684210526315788 0.026> 0.7600000000000001  0    AdaBoostClassifier()
# 0.22807017543859648 0.015> 0.7200000000000001  0    HistGradientBoostingClassifier()
# 0.15789473684210525 0.013> 0.45333333333333337 0    GaussianMixture()
# 0.15789473684210525 0.013> 0.45333333333333337 0    BayesianGaussianMixture()
# 0.14912280701754385 0.040> 0.3866666666666667  0    QuadraticDiscriminantAnalysis()
# 0.11403508771929824 0.015> 0.26                0    <<< Random Baseline >>>
# 0.07894736842105263 0.0    0.06666666666666667 0    OneClassSVM()
# 0.02631578947368421 0.0    0.0                 3    NuSVC()
# 0.02631578947368421 0.0    0.0                 3    RadiusNeighborsClassifier()
# 0.02631578947368421 0.0    0.0                 3    MultinomialNB()
# --------------------------------------------------------------------------------
#
# - - - - - - - - -
#
# --------------------------------------------------------------------------------
# - - - - aggregate accuracy
#
# no  accuracy avg        stddev    excpt   classifier
# --------------------------------------------------------------------------------
# 1   0.8193179398699065  0.154317> 0       CatBoostClassifier
# 2   0.814547586368092   0.152558> 0       ExtraTreesClassifier()
# 3   0.815246987705012   0.149253> 0       RandomForestClassifier()
# 4   0.7899716298794837  0.155138> 0       MLPClassifier()
# 5   0.7978299977933507  0.161342> 0       XGBClassifierWrap({})
# 6   0.7971519114735667  0.162601> 0       GradientBoostingClassifier()
# 7   0.7810042199877956  0.165448> 0       SVC()
# 8   0.7893478657186582  0.171087> 0       HistGradientBoostingClassifier()
# 9   0.7801352439116717  0.152396> 0       LogisticRegression()
# 10  0.7394807394188563  0.233513> 29      LogisticRegressionCV()
# 11  0.790673411836868   0.156280> 0       BaggingClassifier()
# 12  0.7842310580726858  0.154897> 0       DeodelSecond({})
# 13  0.7601520574688835  0.169971> 2       CalibratedClassifierCV()
# 14  0.7612332761351994  0.159936> 0       LinearSVC()
# 15  0.7635172048388772  0.163748> 0       RidgeClassifierCV()
# 16  0.7508336779397196  0.183197> 0       LinearDiscriminantAnalysis()
# 17  0.7485092719625511  0.191002> 0       GaussianProcessClassifier()
# 18  0.7605474052392123  0.164325> 0       RidgeClassifier()
# 19  0.7511190786431344  0.162764> 0       KNeighborsClassifier()
# 20  0.7527820723194764  0.170980> 0       DecisionTreeClassifier()
# 21  0.6824626292845988  0.233851> 0       AdaBoostClassifier()
# 22  0.7458425084901089  0.167179> 0       DeodataDelangaClassifier({})
# 23  0.7177013008322115  0.199048> 0       LabelPropagation()
# 24  0.7172037050442308  0.198814> 0       LabelSpreading()
# 25  0.7248756253332554  0.183148> 0       SGDClassifier()
# 26  0.4965594417559024  0.400420> 163     NuSVC()
# 27  0.7006209070767996  0.170501> 0       BernoulliNB()
# 28  0.6464222414388361  0.275790> 27      QuadraticDiscriminantAnalysis()
# 29  0.6944291192808194  0.194972> 0       GaussianNB()
# 30  0.7072804319395468  0.185326> 0       PassiveAggressiveClassifier()
# 31  0.7060886290588287  0.184414> 0       Perceptron()
# 32  0.7195618416363062  0.166062> 0       ExtraTreeClassifier()
# 33  0.6868618795021658  0.172740> 0       NearestCentroid()
# 34  0.36417857373291407 0.266195> 0       GaussianMixture()
# 35  0.36417857373291407 0.266195> 0       BayesianGaussianMixture()
# 36  0.42655072922830956 0.200240> 0       <<< Random Baseline >>>
# 37  0.12443384700599933 0.113320> 0       OneClassSVM()
# 38  0.06512553189666308 0.209926> 381     MultinomialNB()
# 39  0.03610781440781441 0.165158> 403     RadiusNeighborsClassifier()
# --------------------------------------------------------------------------------
#
#     avg_value: 0.6634389222374674
#     avg_stdev: 0.18687367398465451
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# - - - - aggregate rank score
#
# no  rank aggregate avg  stddev    excpt   classifier
# --------------------------------------------------------------------------------
# 1   0.8158208020050125  0.149720> 0       CatBoostClassifier
# 2   0.787312030075188   0.168140> 0       ExtraTreesClassifier()
# 3   0.7831766917293234  0.151541> 0       RandomForestClassifier()
# 4   0.7142857142857143  0.160822> 0       MLPClassifier()
# 5   0.7047305764411027  0.189297> 0       XGBClassifierWrap({})
# 6   0.699906015037594   0.179308> 0       GradientBoostingClassifier()
# 7   0.6982142857142857  0.168978> 0       SVC()
# 8   0.6963032581453634  0.215828> 0       HistGradientBoostingClassifier()
# 9   0.6822681704260651  0.151809> 0       LogisticRegression()
# 10  0.6640977443609023  0.217376> 29      LogisticRegressionCV()
# 11  0.6384398496240602  0.178211> 0       BaggingClassifier()
# 12  0.6278822055137845  0.186353> 0       DeodelSecond({})
# 13  0.6107769423558898  0.176756> 2       CalibratedClassifierCV()
# 14  0.6086466165413534  0.177413> 0       LinearSVC()
# 15  0.6073308270676692  0.208130> 0       RidgeClassifierCV()
# 16  0.6035401002506265  0.213380> 0       LinearDiscriminantAnalysis()
# 17  0.6033521303258146  0.194356> 0       GaussianProcessClassifier()
# 18  0.5954573934837093  0.207808> 0       RidgeClassifier()
# 19  0.5341165413533835  0.169592> 0       KNeighborsClassifier()
# 20  0.4901315789473684  0.219346> 0       DecisionTreeClassifier()
# 21  0.4843358395989975  0.223040> 0       AdaBoostClassifier()
# 22  0.4791979949874687  0.180115> 0       DeodataDelangaClassifier({})
# 23  0.46864035087719297 0.216137> 0       LabelPropagation()
# 24  0.46770050125313284 0.213397> 0       LabelSpreading()
# 25  0.46171679197994986 0.159707> 0       SGDClassifier()
# 26  0.4270989974937343  0.337640> 163     NuSVC()
# 27  0.4232456140350877  0.225216> 0       BernoulliNB()
# 28  0.4225877192982456  0.246589> 27      QuadraticDiscriminantAnalysis()
# 29  0.4149122807017544  0.224663> 0       GaussianNB()
# 30  0.4139724310776942  0.166390> 0       PassiveAggressiveClassifier()
# 31  0.39840225563909776 0.145015> 0       Perceptron()
# 32  0.3944862155388471  0.165711> 0       ExtraTreeClassifier()
# 33  0.37296365914786966 0.209053> 0       NearestCentroid()
# 34  0.19298245614035087 0.204069> 0       GaussianMixture()
# 35  0.19298245614035087 0.204069> 0       BayesianGaussianMixture()
# 36  0.1525689223057644  0.106878> 0       <<< Random Baseline >>>
# 37  0.0681390977443609  0.032403> 0       OneClassSVM()
# 38  0.05291353383458646 0.110852> 381     MultinomialNB()
# 39  0.04536340852130326 0.103441> 403     RadiusNeighborsClassifier()
# --------------------------------------------------------------------------------
#
#     avg_value: 0.5
#     avg_stdev: 0.1835530664456773
#
# --------------------------------------------------------------------------------
#
# - - BatchCsvAccuracyTest (v1.1.1) - end
#
# --------------------------------------------------------------------------------
#
#
# - - - - - - - - - - - - - - - - - -
# - - - - - - - - - - - - - - - - - -
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - - python version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# - - - - scikit-learn version: 1.2.2
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# - - - test end
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# ## End

# %%
print()
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
CrtTimeStamp()
print("- - - - - - - - - - - - - - - - - - - - - - - - - - - - ")
print()
# Out:
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# time_stamp: 2024-03-04 04:43:30
# - - - - - - - - - - - - - - - - - - - - - - - - - - - -
